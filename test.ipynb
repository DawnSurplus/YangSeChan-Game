# %%
# %pip install ollama
# %pip install gradio

# %%
# import gradio as gr
# import random
# import ollama

# # 기존 Player 및 LLMPlayer 클래스 정의
# class Player:
#     def __init__(self, name: str):
#         self.name = name
#         self.character = ""

#     def check_character(self, character):
#         return (self.character == character)

# class LLMPlayer(Player):
#     MODEL_NAME="EEVE-Korean-10.8B"
#     SYSTEM_PROMPT = ("""
#         당신은 양세찬 게임 전문 참가자입니다. 반드시 다음 규칙을 따라야 합니다:

#         1. 질문 생성 규칙
#         - 예/아니오로 답변 가능한 형태
#         - 캐릭터 이름 직접 언급 금지
#         - 주제와 관련된 내용

#         2. 답변 규칙
#         - 반드시 사실에 기반해 답변
#         - '예', '아니오'로만 답변
#         - 추가 설명 없이 3단어 이내로 응답

#         3. 추측 규칙
#         - 반드시 한 명의 '인물'로만 답변
#         - 불확실하면 '모름'이라고 답변
#     """)
    
#     def __init__(self, name):
#         super().__init__(name)        
#         self.messages = [{"role": "system", "content": self.__class__.SYSTEM_PROMPT}]

#     # 자신 캐릭터 관련 질문 (Question)
#     def get_Q_res(self, content):
#         self.messages.append({"role": "user", "content": content})
       
#         q_res = ollama.chat(
#             model=self.__class__.MODEL_NAME,
#             messages=self.messages,
#         )['message']['content']

#         self.messages.append({"role": "assistant", "content": q_res})

#         return q_res
    
#     # 상대 질문에 대한 답 (Answer)
#     def get_A_res(self, content):
#         a_res = ollama.chat(
#             model=self.__class__.MODEL_NAME,
#             messages=[
#                 {"role": "system", "content": self.__class__.SYSTEM_PROMPT},
#                 {"role": "user", "content": content}
#             ],
#         )['message']['content']

#         return a_res
    
#     # 내 캐릭터 유추 (Result)
#     def get_R_res(self, content):
#         self.messages.append({"role": "user", "content": content})
       
#         r_res = ollama.chat(
#             model=self.__class__.MODEL_NAME,
#             messages=self.messages,
#         )['message']['content']

#         self.messages.append({"role": "assistant", "content": r_res})

#         return r_res

#     def add_message(self, role, content):
#         self.messages.append({"role": role, "content": content})

# # 기존 주제 및 캐릭터 목록
# TOPICS = ["연예인", "영화 인물", "드라마 인물", "위인", "캐릭터"]
# CHARACTERS = {
#     "연예인": [
#         "유재석", "아이유", "BTS 진", "블랙핑크 제니", "송강호", "김태리", "이영자", "박보검", "전지현", "이병헌",
#         "공유", "한효주", "김수현", "김고은", "박명수", "이승기", "박서준", "정해인", "차은우", "수지"
#     ],
#     "영화 인물": [
#         "해리 포터", "헤르미온느 그레인저", "론 위즐리", "인디아나 존스", "제임스 본드", "다스 베이더", "루크 스카이워커", "한 솔로", "조커", "배트맨",
#         "포레스트 검프", "토니 스타크", "캡틴 아메리카", "엘사", "올라프", "도로시", "토토", "한니발 렉터", "토니 몬타나", "존 윅"                
#     ],
#     "드라마 인물": [
#         "김신", "지은탁", "이헌", "고애신", "도민준", "천송이", "성덕선", "최택", "박새로이", "조이서",
#         "김주원", "길라임", "이강", "채송화", "이준혁", "차수현", "윤세리", "리정혁", "장만월", "구찬성"
#     ],
#     "위인": [
#         "세종대왕", "이순신", "간디", "아인슈타인", "링컨", "나폴레옹", "클레오파트라", "칭기즈칸", "넬슨 만델라", "마리 퀴리",
#         "플라톤", "아리스토텔레스", "에디슨", "테슬라", "다윈", "갈릴레이", "코페르니쿠스", "뉴턴", "파스퇴르", "멘델"
#     ],
#     "캐릭터": [
#         "도라에몽", "피카츄", "뽀로로", "미키마우스", "슈퍼마리오", "소닉", "톰", "제리", "스폰지밥", "심슨",
#         "짱구", "곰돌이 푸", "미니언", "토토로", "포뇨", "둘리", "고길동", "베지터", "카카로트", "루피"
#     ]
# }

# # 기존 PROMPT 정의
# QUESTION_PROMPT = (
#     "다음 조건에 맞는 질문을 생성하세요:\n"
#     "1. 내 캐릭터를 추론할 수 있는 내용\n"
#     "2. 캐릭터 이름직접 언급 금지\n"
#     "3. '예/아니오' 혹은 단답형으로 답변 가능할 수 있는 내용\n\n"
#     # 예시 생략
# )

# ANSWER_PROMPT = (
#     "질문 '{question}'에 대해 캐릭터('{character}')가 맞는지 답변:\n"
#     "1. '예'/'아니오' 또는 '단답형'으로만 답변\n"
#     "2. 캐릭터 이름('{character}') 언급 금지\n"
#     "3. 사실에 기반한 대답\n\n"
#     # 예시 생략
# )

# GUESS_PROMPT = (
#     "현재까지의 정보로 '내 캐릭터가 누구인지 추측'하세요:\n"
#     "1. 반드시 한 명의 '인물' 또는 '가상인물'로 답변\n"
#     "2. 모를 경우 '모름'\n\n"
#     # 예시 생략
# )

# # 게임 상태 관리 변수
# game_state = {
#     "players": {},
#     "topic": "",
#     "current_player_idx": 0,
#     "round": 1,
#     "game_started": False,
#     "logs": [],
#     "current_player": "",
#     "winner": None
# }

# # 플레이어 생성 함수
# def create_players(player_count):
#     players = {}
#     # User
#     players["user"] = Player("user")
#     # AI
#     for i in range(1, player_count):
#         name = f"ai-{i}"
#         players[name] = LLMPlayer(name)
#     return players

# # 캐릭터 할당 함수
# def random_characters(topic, player_count):
#     return random.sample(CHARACTERS[topic], k=player_count)

# # 게임 시작 함수
# def start_game(topic, player_count):
#     # 게임 초기화
#     game_state["topic"] = topic
#     game_state["players"] = create_players(player_count)
#     game_state["round"] = 1
#     game_state["current_player_idx"] = 0
#     game_state["current_player"] = "user"
#     game_state["game_started"] = True
#     game_state["logs"] = []
#     game_state["winner"] = None
    
#     # 캐릭터 할당
#     characters = random_characters(topic, player_count)
#     for i, (name, player) in enumerate(game_state["players"].items()):
#         player.character = characters[i]
    
#     # 로그 초기화
#     logs = []
#     logs.append(f"게임 시작!!! 주제: '{topic}'")
#     logs.append("각 플레이어에게 캐릭터를 할당했습니다.")
#     for name, player in game_state["players"].items():
#         if name == "user":
#             logs.append(f"- {name} : {player.character}")
#         else:
#             logs.append(f"- {name} : [비밀]")
    
#     logs.append(f"\n--- {game_state['round']}라운드 ---")
#     logs.append(f"\n[{game_state['current_player']}의 차례]")
    
#     game_state["logs"] = logs
    
#     # 로그 텍스트 생성
#     log_sections = {}
#     for name in game_state["players"].keys():
#         log_sections[name] = "\n".join(logs)
    
#     return (
#         "게임이 시작되었습니다. 당신의 차례입니다!",
#         log_sections.get("user", ""),
#         log_sections.get("ai-1", ""),
#         log_sections.get("ai-2", ""),
#         log_sections.get("ai-3", ""),
#         True,  # 질문 입력 활성화
#         False,  # 답변 입력 비활성화
#         False,  # 정답 입력 비활성화
#     )

# # 질문 처리 함수
# def ask_question(question):
#     if not game_state["game_started"] or game_state["winner"]:
#         return "게임이 시작되지 않았거나 이미 종료되었습니다."
    
#     current_player = game_state["current_player"]
#     logs = game_state["logs"].copy()
    
#     # 질문 로그 추가
#     logs.append(f"'{current_player}' 질문 >> {question}")
    
#     # 다른 플레이어들의 답변 받기
#     for name, player in game_state["players"].items():
#         if name == current_player:
#             continue
        
#         if name != "user":
#             answer = player.get_A_res(
#                 ANSWER_PROMPT.format(
#                     character=game_state["players"][current_player].character,
#                     question=question
#                 )
#             )
#             logs.append(f"{name} 답변 >> {answer}")
    
#     game_state["logs"] = logs
    
#     # 로그 텍스트 업데이트
#     log_sections = {}
#     for name in game_state["players"].keys():
#         log_sections[name] = "\n".join(logs)
    
#     return (
#         "질문이 등록되었습니다. 정답을 맞춰보세요!",
#         log_sections.get("user", ""),
#         log_sections.get("ai-1", ""),
#         log_sections.get("ai-2", ""),
#         log_sections.get("ai-3", ""),
#         False,  # 질문 입력 비활성화
#         False,  # 답변 입력 비활성화
#         True,   # 정답 입력 활성화
#     )

# # 답변 처리 함수
# def answer_question(answer):
#     if not game_state["game_started"] or game_state["winner"]:
#         return "게임이 시작되지 않았거나 이미 종료되었습니다."
    
#     current_player = game_state["current_player"]
#     logs = game_state["logs"].copy()
    
#     # 답변 로그 추가
#     logs.append(f"{current_player} 답변 >> {answer}")
    
#     game_state["logs"] = logs
    
#     # 로그 텍스트 업데이트
#     log_sections = {}
#     for name in game_state["players"].keys():
#         log_sections[name] = "\n".join(logs)
    
#     return (
#         "답변이 등록되었습니다. 다음 플레이어의 차례입니다.",
#         log_sections.get("user", ""),
#         log_sections.get("ai-1", ""),
#         log_sections.get("ai-2", ""),
#         log_sections.get("ai-3", ""),
#         False,  # 질문 입력 비활성화
#         False,  # 답변 입력 비활성화
#         False,  # 정답 입력 비활성화
#     )

# # 정답 추측 처리 함수
# def guess_character(guess):
#     if not game_state["game_started"] or game_state["winner"]:
#         return "게임이 시작되지 않았거나 이미 종료되었습니다."
    
#     current_player = game_state["current_player"]
#     current_player_obj = game_state["players"][current_player]
#     logs = game_state["logs"].copy()
    
#     # 정답 로그 추가
#     logs.append(f"{current_player} 정답 >> {guess}")
    
#     # 정답 판별
#     if guess and guess.strip() == current_player_obj.character:
#         logs.append(f"🎉 {current_player}님이 정답을 맞췄습니다! 게임 종료")
#         game_state["winner"] = current_player
#     else:
#         logs.append(f"{current_player}님은 정답을 맞추지 못했습니다.")
        
#         # 다음 플레이어로 넘어가기
#         player_names = list(game_state["players"].keys())
#         game_state["current_player_idx"] = (game_state["current_player_idx"] + 1) % len(player_names)
#         game_state["current_player"] = player_names[game_state["current_player_idx"]]
        
#         # 한 라운드가 끝났는지 확인
#         if game_state["current_player_idx"] == 0:
#             game_state["round"] += 1
#             logs.append(f"\n--- {game_state['round']}라운드 ---")
        
#         logs.append(f"\n[{game_state['current_player']}의 차례]")
        
#         # AI 플레이어 차례면 질문 자동 생성
#         if game_state["current_player"] != "user" and not game_state["winner"]:
#             ai_player = game_state["players"][game_state["current_player"]]
#             ai_question = ai_player.get_Q_res(QUESTION_PROMPT)
#             logs.append(f"'{game_state['current_player']}' 질문 >> {ai_question}")
            
#             # 다른 플레이어들의 답변 받기
#             for name, player in game_state["players"].items():
#                 if name == game_state["current_player"]:
#                     continue
                
#                 if name == "user":
#                     logs.append(f"{name}님의 답변을 기다리는 중...")
#                 else:
#                     answer = player.get_A_res(
#                         ANSWER_PROMPT.format(
#                             character=ai_player.character,
#                             question=ai_question
#                         )
#                     )
#                     logs.append(f"{name} 답변 >> {answer}")
    
#     game_state["logs"] = logs
    
#     # 로그 텍스트 업데이트
#     log_sections = {}
#     for name in game_state["players"].keys():
#         log_sections[name] = "\n".join(logs)
    
#     question_active = False
#     answer_active = False
#     guess_active = False
    
#     if not game_state["winner"]:
#         if game_state["current_player"] == "user":
#             question_active = True
#         else:
#             answer_active = True
    
#     return (
#         "다음 플레이어의 차례입니다." if not game_state["winner"] else f"게임 종료! 승자: {game_state['winner']}",
#         log_sections.get("user", ""),
#         log_sections.get("ai-1", ""),
#         log_sections.get("ai-2", ""),
#         log_sections.get("ai-3", ""),
#         question_active,
#         answer_active,
#         guess_active,
#     )

# # 그라디오 UI 구성
# with gr.Blocks(title="양세찬 게임") as demo:
#     gr.Markdown("# 양세찬 게임 - 캐릭터 맞추기")
    
#     with gr.Row():
#         topic_dropdown = gr.Dropdown(choices=TOPICS, label="주제 선택", value=TOPICS[0])
#         player_count_slider = gr.Slider(minimum=2, maximum=4, step=1, value=2, label="플레이어 수 (사용자 포함)")
#         start_button = gr.Button("게임 시작")
    
#     status_text = gr.Textbox(label="게임 상태", interactive=False)
    
#     with gr.Tab("게임 진행"):
#         with gr.Row():
#             question_input = gr.Textbox(label="질문", placeholder="상대방 캐릭터에 대한 질문을 입력하세요...", interactive=True)
#             answer_input = gr.Textbox(label="답변", placeholder="질문에 대한 답변을 입력하세요...", interactive=True)
#             guess_input = gr.Textbox(label="정답", placeholder="캐릭터 이름을 입력하세요 (패스는 빈칸으로)...", interactive=True)
            
#         with gr.Row():
#             question_button = gr.Button("질문하기")
#             answer_button = gr.Button("답변하기")
#             guess_button = gr.Button("정답 제출")
    
#     with gr.Tab("게임 로그"):
#         with gr.Row():
#             user_log = gr.Textbox(label="User 로그", interactive=False, lines=20)
#             ai1_log = gr.Textbox(label="AI-1 로그", interactive=False, lines=20)
        
#         with gr.Row():
#             ai2_log = gr.Textbox(label="AI-2 로그", interactive=False, lines=20)
#             ai3_log = gr.Textbox(label="AI-3 로그", interactive=False, lines=20)
    
#     # 이벤트 연결
#     start_button.click(
#         fn=start_game,
#         inputs=[topic_dropdown, player_count_slider],
#         outputs=[status_text, user_log, ai1_log, ai2_log, ai3_log, question_input, answer_input, guess_input]
#     )
    
#     question_button.click(
#         fn=ask_question,
#         inputs=[question_input],
#         outputs=[status_text, user_log, ai1_log, ai2_log, ai3_log, question_input, answer_input, guess_input]
#     )
    
#     answer_button.click(
#         fn=answer_question,
#         inputs=[answer_input],
#         outputs=[status_text, user_log, ai1_log, ai2_log, ai3_log, question_input, answer_input, guess_input]
#     )
    
#     guess_button.click(
#         fn=guess_character,
#         inputs=[guess_input],
#         outputs=[status_text, user_log, ai1_log, ai2_log, ai3_log, question_input, answer_input, guess_input]
#     )

# # 서버 실행
# if __name__ == "__main__":
#     demo.launch()

# %%
import ollama



class Player:
    def __init__(self, name: str):
        self.name = name
        self.character = ""

    def check_character(self, character):
        return (self.character == character)



class LLMPlayer(Player):
    MODEL_NAME="EEVE-Korean-10.8B"
    SYSTEM_PROMPT = ("""
        당신은 양세찬 게임 전문 참가자입니다. 반드시 다음 규칙을 따라야 합니다:

        1. 질문 생성 규칙
        - 예/아니오로 답변 가능한 형태
        - 캐릭터 이름 직접 언급 금지
        - 주제와 관련된 내용

        2. 답변 규칙
        - 반드시 사실에 기반해 답변
        - '예', '아니오'로만 답변
        - 추가 설명 없이 3단어 이내로 응답

        3. 추측 규칙
        - 반드시 한 명의 '인물'로만 답변
        - 불확실하면 '모름'이라고 답변
    """)
    


    def __init__(self, name):
        super().__init__(name)        
        self.messages = [{"role": "system", "content": self.__class__.SYSTEM_PROMPT}]



    # 자신 캐릭터 관련 질문 (Question)
    def get_Q_res(self, content):
        self.messages.append({"role": "user", "content": content})
       
        q_res = ollama.chat(
            model=self.__class__.MODEL_NAME,
            messages=self.messages,
        )['message']['content']

        self.messages.append({"role": "assistant", "content": q_res})

        return q_res
    


    # 상대 질문에 대한 답 (Answer)
    def get_A_res(self, content):
        a_res = ollama.chat(
            model=self.__class__.MODEL_NAME,
            messages=[
                {"role": "system", "content": self.__class__.SYSTEM_PROMPT},
                {"role": "user", "content": content}
            ],
        )['message']['content']

        return a_res
    


    # 내 캐릭터 유추 (Result)
    def get_R_res(self, content):
        self.messages.append({"role": "user", "content": content})
       
        r_res = ollama.chat(
            model=self.__class__.MODEL_NAME,
            messages=self.messages,
        )['message']['content']

        self.messages.append({"role": "assistant", "content": r_res})

        return r_res



    def add_message(self, role, content):
        self.messages.append({"role": role, "content": content})

# %%
# 주제 목록
TOPICS = ["연예인", "영화 인물", "드라마 인물", "위인", "캐릭터"]

# 각 주제별 예시 인물
CHARACTERS = {
    "연예인": [
        "유재석", "아이유", "BTS 진", "블랙핑크 제니", "송강호", "김태리", "이영자", "박보검", "전지현", "이병헌",
        "공유", "한효주", "김수현", "김고은", "박명수", "이승기", "박서준", "정해인", "차은우", "수지"
    ],
    "영화 인물": [
        "해리 포터", "헤르미온느 그레인저", "론 위즐리", "인디아나 존스", "제임스 본드", "다스 베이더", "루크 스카이워커", "한 솔로", "조커", "배트맨",
        "포레스트 검프", "토니 스타크", "캡틴 아메리카", "엘사", "올라프", "도로시", "토토", "한니발 렉터", "토니 몬타나", "존 윅"                
    ],
    "드라마 인물": [
        "김신", "지은탁", "이헌", "고애신", "도민준", "천송이", "성덕선", "최택", "박새로이", "조이서",
        "김주원", "길라임", "이강", "채송화", "이준혁", "차수현", "윤세리", "리정혁", "장만월", "구찬성"
    ],
    "위인": [
        "세종대왕", "이순신", "간디", "아인슈타인", "링컨", "나폴레옹", "클레오파트라", "칭기즈칸", "넬슨 만델라", "마리 퀴리",
        "플라톤", "아리스토텔레스", "에디슨", "테슬라", "다윈", "갈릴레이", "코페르니쿠스", "뉴턴", "파스퇴르", "멘델"
    ],
    "캐릭터": [
        "도라에몽", "피카츄", "뽀로로", "미키마우스", "슈퍼마리오", "소닉", "톰", "제리", "스폰지밥", "심슨",
        "짱구", "곰돌이 푸", "미니언", "토토로", "포뇨", "둘리", "고길동", "베지터", "카카로트", "루피"
    ]
}

# %%
import random

def random_topic():    
    return random.choice(TOPICS)


def random_characters(topic, player_count):
    print(CHARACTERS[topic])
    return random.choices(CHARACTERS[topic], k=player_count)

# %%
def create_players(player_count):
    players = {}

    # User
    players["user"] = Player("user")

    # AI
    for i in range(1, player_count):
        name = f"ai-{i}"
        players[name] = LLMPlayer(name)
    
    return players



# 게임 준비
player_count = 3
players = create_players(player_count)

# %%
# 주제 및 캐릭터 할당
topic = random_topic()
characters = random_characters(topic, player_count)

# 캐릭터 할당
for (player, character) in zip(players.values(), characters):
    player.character = character
# Out:
# ['김신', '지은탁', '이헌', '고애신', '도민준', '천송이', '성덕선', '최택', '박새로이', '조이서', '김주원', '길라임', '이강', '채송화', '이준혁', '차수현', '윤세리', '리정혁', '장만월', '구찬성']

# %%
# PROMPT 정의
QUESTION_PROMPT = (
    "다음 조건에 맞는 질문을 생성하세요:\n"
    "1. 내 캐릭터를 추론할 수 있는 내용\n"
    "2. 캐릭터 이름직접 언급 금지\n"
    "3. '예/아니오' 혹은 단답형으로 답변 가능할 수 있는 내용\n\n"

    "예시:\n"
    "- 예.\n"
    "- 네.\n"
    "- 아니오.\n"
    "- 아뇨.\n"
    "- 남자입니까?\n"
    "- 여자입니까?\n"
    "- 한국인입니까?\n"
    "- 외국인입니까?\n"
)

ANSWER_PROMPT = (
    "질문 '{question}'에 대해 캐릭터('{character}')가 맞는지 답변:\n"
    "1. '예'/'아니오' 또는 '단답형'으로만 답변\n"
    "2. 캐릭터 이름('{character}')을 응답에 포함시키지 말 것\n"
    "3. 사실에 기반한 대답\n\n"

    "예시:\n"
    "- 예, 밀짚모자를 씁니다.\n"
    "- 아니오, 미국드라마입니다.\n"
    "- 모름\n"
    "- 네, 맞아요.\n"
    "- 아니요, 아닙니다.\n"
    "- 남자예요.\n"
    "- 여자예요.\n"
    "- 한국인이에요.\n"
    "- 외국인이에요.\n"
)

GUESS_PROMPT = (
    "현재까지의 정보로 '내 캐릭터가 누구인지 추측'하세요:\n"
    "1. 반드시 한 명의 '인물' 또는 '가상인물'로 답변\n"
    "2. 모를 경우 '모름'\n\n"

    "예시:\n"
    "- 유재석\n"
    "- 해리포터\n"
    "- 둘리\n"
    "- 김구\n"
    "- 박효신\n"
    "- 모름\n"
    "- 포레스트 검프\n"
    "- 토니 스타크\n"
    "- 캡틴 아메리카\n"
    "- 길라임\n"
    "- 이강\n"
    "- 채송화\n"
    "- 플라톤\n"
    "- 아리스토텔레스\n"
    "- 에디슨\n"
    "- 테슬라\n"
    "- 짱구\n"
    "- 곰돌이 푸\n"
    "- 미니언\n"
    "- 토토로\n"
)


def play_game(players, topic, max_rounds=20):
    print(f"게임 시작!!!\n>>>> 주제 : '{topic}'\n")
    print("각 플레이어에게 캐릭터를 할당했했습니다.")
    for (name, player) in players.items():
        print(f"- {name} : {player.character}")
    
    winner = None
    round_num = 1

    while round_num <= max_rounds and winner is None:
        print(f"\n--- {round_num}라운드 ---")
        
        for (player_name, player) in players.items():
            player = players[player_name]
            print(f"\n[{player_name}의 차례]")
            
            # 질문
            question=""
            if (player_name == "user"):
                question = input("내 캐릭터에 대한 질문 >> ")
            else:
                question = player.get_Q_res(QUESTION_PROMPT)
            print(f"'{player_name}' 질문 >> {question}")
            
            # 답변
            for (other_name, other_player) in players.items():
                # 질문한 당사자는 건너뜀
                if (other_name == player_name):
                    continue
                
                answer=""
                if (other_name == "user"):
                    answer = input(f"{player_name}의 질문에 답변 >> ")
                else:
                    answer = other_player.get_A_res(
                        ANSWER_PROMPT.format(
                            character=player.character,
                            question=question
                        ),
                    )
                print(f"{other_name} 답변 >> {answer}")

            
            # 정답
            guess=""
            if (player_name == "user"):
                guess = input("정답 (패스 Enter) : ")
            else:
                guess = player.get_R_res(GUESS_PROMPT)
            print(f"{player_name} 정답 >> {guess}")


            # 정답 판별
            if guess and guess.strip() == player.character:
                print(f"🎉 {player_name}님이 정답을 맞췄습니다! 게임 종료")
                winner = player_name
                break
            else:
                print(f"{player_name}님은 정답을 맞추지 못했습니다.")

        round_num += 1

    if winner:
        print(f"\n게임 승자: {winner} (정답: {players[winner].character})")
    else:
        print("\n아쉽게도 아무도 정답을 맞히지 못했습니다.")


# 게임 플레이 시작
play_game(players, topic)
# Out:
# 게임 시작!!!
# >>>> 주제 : '드라마 인물'
#
# 각 플레이어에게 캐릭터를 할당했했습니다.
# - user : 지은탁
# - ai-1 : 이헌
# - ai-2 : 최택
#
# --- 1라운드 ---
#
# [user의 차례]
# 'user' 질문 >> 여자인가요?
# ai-1 답변 >> 1. 예, 여자인가요? 아니오, 남자인데요.
# ai-2 답변 >> 1. 아니오, 그녀는 여자아입니다.
# 2. 예, 지은탁은 한국인입니다.
# 3. 모름
# 4. 아니오, 그녀가 주인공은 아닙니다.
# 5. 아니오, 그녀는 미국 드라마에 나오지 않습니다.
# user 정답 >>
# user님은 정답을 맞추지 못했습니다.
#
# [ai-1의 차례]
# 'ai-1' 질문 >> 1. 내 캐릭터는 무술가입니까?
# user 답변 >> 몰라요
# ai-2 답변 >> 1. 예
# ai-1 정답 >> 1. 내 캐릭터는 무술인입니까?
# ai-1님은 정답을 맞추지 못했습니다.
#
# [ai-2의 차례]
# 'ai-2' 질문 >> 질문: 캐릭터의 성별은 무엇입니까?
# user 답변 >> 남자
# ai-1 답변 >> 남자예요.
#
# 신뢰도: 100%
# ai-2 정답 >> 추측: [당신의 캐릭터]는 남자입니까, 여자입니까?
# ai-2님은 정답을 맞추지 못했습니다.
#
# --- 2라운드 ---
#
# [user의 차례]

# %%
#
